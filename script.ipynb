# %% [markdown]
# # Nike Project

# %%
import pandas as pd

# %%
df = pd.read_csv('nike_data_2022_09.csv')

# %%
df.price.hist();

# %% [markdown]
# ### Avg Rating

# %%
df.avg_rating.hist()
# Out:
# <AxesSubplot: >
